# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_counts = Counter(int_words)
threshold = 1e-5
total_count = len(int_words)
frequencies = {word: count/total_count for word, count in word_counts.items()}

p_drop = {word: 1 - np.sqrt(threshold/frequencies[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    r = np.random.randint(1, window_size+1)
    start = idx - r
    stop = idx + r
    
    if start < 0:
        start = 0
    if stop > len(words) - 1:
        stop = len(words) - 1
    
    return list(set(words[start:idx] + words[idx+1:stop+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6192 0.0864 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5869 0.0837 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4798 0.0836 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5777 0.0842 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4999 0.0833 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5359 0.0828 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5484 0.0841 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5790 0.0848 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4745 0.0864 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4491 0.0872 sec/batch
# Nearest to where: hiragana, chatting, bradykinin, monsieur, sweets, blackbird, partnered, warehousing,
# Nearest to six: fiscally, diable, lowe, deontology, ecclesiastic, canopus, kbit, wholesome,
# Nearest to nine: stellar, turkmenistan, churchill, ethnography, salty, catoctin, movies, abundantly,
# Nearest to years: elis, bighorn, bultmann, knob, timid, welding, uballit, excellency,
# Nearest to d: settling, galahad, displays, snipe, asoka, obsoletes, lagrangian, turntable,
# Nearest to first: liston, takers, ic, mach, sludge, hazel, dworkin, root,
# Nearest to by: rail, tombo, roosevelts, voortrekkers, transept, heavenly, highways, transboundary,
# Nearest to on: pekka, hypertalk, election, earless, jef, instantly, pehr, barred,
# Nearest to older: jeet, constricted, unfiltered, clover, crowd, cryptology, ippon, encodings,
# Nearest to prince: botanical, milestone, molded, vdp, systematic, gliese, tall, universal,
# Nearest to brother: takano, argyll, azrael, granules, abbasid, panels, canova, teleoperation,
# Nearest to existence: ramses, superconducting, somerled, amniotes, repelling, adamson, myself, lymphatic,
# Nearest to running: dominance, disconnect, endosymbiotic, fired, dissertation, evening, complutense, muzzleloaders,
# Nearest to stage: wallis, bentsen, greifswald, freeview, encoded, bundesland, mandelson, liqueur,
# Nearest to nobel: dobruja, runestone, tribunal, choo, eloquent, emmanuelle, theropod, hodges,
# Nearest to centre: majoritarian, drilled, tones, outcomes, vegetative, luke, recite, scholem,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5025 0.0885 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3847 0.0888 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2971 0.0896 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2632 0.0896 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2095 0.0893 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1703 0.0901 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0912 0.0919 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0689 0.0908 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0108 0.0903 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9939 0.0909 sec/batch
# Nearest to where: chatting, correctly, belief, provinces, custom, teaching, sweets, bradykinin,
# Nearest to six: fiscally, diable, lowe, deontology, kbit, canopus, that, refuse,
# Nearest to nine: stellar, turkmenistan, churchill, arts, movies, ethnography, non, live,
# Nearest to years: excellency, century, allegedly, knob, bruin, right, elis, award,
# Nearest to d: settling, galahad, displays, unique, peoples, set, turntable, exchanging,
# Nearest to first: republics, constraints, ic, conclusion, mach, liston, pieces, root,
# Nearest to by: rail, tombo, highways, definitions, hat, change, roosevelts, heavenly,
# Nearest to on: pekka, election, instantly, hypertalk, ambitions, jef, earless, barred,
# Nearest to older: jeet, crowd, constricted, factorization, clover, cryptology, focus, discovered,
# Nearest to prince: botanical, milestone, systematic, molded, tall, universal, resemble, has,
# Nearest to brother: takano, granules, azrael, panels, argyll, protectress, abbasid, prone,
# Nearest to existence: myself, estimate, unknown, ramses, superconducting, wings, findings, repelling,
# Nearest to running: dominance, dissertation, evening, fired, disconnect, structures, endosymbiotic, benchmark,
# Nearest to stage: bentsen, wallis, encoded, demands, bundesland, greifswald, freeview, inseparable,
# Nearest to nobel: runestone, dobruja, eloquent, tribunal, choo, emmanuelle, authoritarianism, hodges,
# Nearest to centre: majoritarian, tones, outcomes, involved, china, drilled, vegetative, luke,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9233 0.0922 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8927 0.0915 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8950 0.0921 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8690 0.0917 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8230 0.0916 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8062 0.0919 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7809 0.0931 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7953 0.0920 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8032 0.0923 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7625 0.0928 sec/batch
# Nearest to where: chatting, hiragana, correctly, provinces, sweets, custom, mead, differently,
# Nearest to six: fiscally, lowe, leap, diable, legacy, three, deontology, egypt,
# Nearest to nine: stellar, turkmenistan, ethnography, churchill, seven, movies, deux, failures,
# Nearest to years: bultmann, excellency, allegedly, quiet, reverted, timid, elis, welding,
# Nearest to d: settling, galahad, displays, exchanging, lagrangian, june, asoka, suffolk,
# Nearest to first: ic, pieces, yugoslavia, liston, constraints, mach, accused, conclusion,
# Nearest to by: rail, tombo, roosevelts, highways, voortrekkers, definitions, hat, heavenly,
# Nearest to on: pekka, election, earless, barred, hypertalk, instantly, pehr, ambitions,
# Nearest to older: jeet, constricted, crowd, paramount, discovered, clover, gaseous, roberts,
# Nearest to prince: milestone, botanical, molded, colourful, percy, systematic, tall, tender,
# Nearest to brother: takano, granules, panels, prone, azrael, wars, backward, protectress,
# Nearest to existence: ramses, myself, estimate, repelling, superconducting, threatens, offending, tsar,
# Nearest to running: dominance, dissertation, fired, endosymbiotic, evening, gaps, disconnect, benchmark,
# Nearest to stage: wallis, bentsen, encoded, demands, greifswald, freeview, germanic, guarded,
# Nearest to nobel: runestone, eloquent, tribunal, dobruja, workings, emmanuelle, quartets, authoritarianism,
# Nearest to centre: majoritarian, tones, outcomes, drilled, vegetative, lion, recite, jules,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7627 0.0945 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7718 0.0933 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6992 0.0936 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7516 0.0933 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7474 0.0941 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6992 0.0938 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7084 0.0929 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7124 0.0931 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7171 0.0933 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6461 0.0936 sec/batch
# Nearest to where: hiragana, chatting, sweets, devout, provinces, correctly, mead, custom,
# Nearest to six: lowe, three, fiscally, leap, naturalist, marshal, legacy, egypt,
# Nearest to nine: seven, turkmenistan, stellar, ethnography, deux, novelist, live, movies,
# Nearest to years: elis, bultmann, bighorn, reverted, allegedly, negatives, timid, supersessionism,
# Nearest to d: settling, ois, june, galahad, fran, lagrangian, asoka, writer,
# Nearest to first: biennial, yugoslavia, liston, ic, takers, accused, pieces, dworkin,
# Nearest to by: tombo, rail, roosevelts, highways, endeavors, voortrekkers, hat, mukti,
# Nearest to on: pekka, earless, hypertalk, election, barred, pehr, instantly, amphitheatre,
# Nearest to older: jeet, constricted, kern, gaseous, discovered, roberts, moabites, factorization,
# Nearest to prince: milestone, percy, molded, botanical, wtro, colourful, interdiction, austria,
# Nearest to brother: takano, granules, wars, panels, italian, eight, argyll, protectress,
# Nearest to existence: ramses, repelling, offending, lexical, airflow, lymphatic, superconducting, somerled,
# Nearest to running: dominance, dissertation, endosymbiotic, evening, fired, disconnect, gaps, terminator,
# Nearest to stage: wallis, bentsen, freeview, encoded, greifswald, glenn, demands, guarded,
# Nearest to nobel: runestone, eloquent, baritone, dobruja, tribunal, authoritarianism, quartets, workings,
# Nearest to centre: majoritarian, jules, tones, outcomes, vegetative, lion, recite, drilled,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6763 0.0941 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6509 0.0934 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5894 0.0934 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6236 0.0936 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6358 0.0929 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6492 0.0927 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5817 0.0691 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5466 0.0954 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5206 0.0952 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5094 0.0945 sec/batch
# Nearest to where: hiragana, chatting, correctly, devout, lances, anhydrous, represents, mead,
# Nearest to six: lowe, three, naturalist, fiscally, marshal, philanthropist, leap, flavorings,
# Nearest to nine: seven, actress, journalist, novelist, turkmenistan, ethnography, churchill, georg,
# Nearest to years: elis, bighorn, bultmann, supersessionism, welding, negatives, reverted, jacinto,
# Nearest to d: ois, writer, fran, musician, graham, hendrik, galahad, settling,
# Nearest to first: liston, biennial, yugoslavia, takers, dworkin, ic, donations, accused,
# Nearest to by: tombo, roosevelts, hat, voortrekkers, transept, legitimately, endeavors, highways,
# Nearest to on: pekka, earless, amphitheatre, hypertalk, pehr, barred, instantly, election,
# Nearest to older: jeet, constricted, kern, moabites, discovered, gaseous, clover, ippon,
# Nearest to prince: percy, wtro, milestone, swimmer, born, austria, botanical, marco,
# Nearest to brother: takano, granules, wars, abbasid, argyll, dmitry, italian, teleoperation,
# Nearest to existence: lexical, lymphatic, repelling, myself, amniotes, ramses, airflow, phaistos,
# Nearest to running: endosymbiotic, dominance, dissertation, fired, evening, gaps, disconnect, muzzleloaders,
# Nearest to stage: wallis, bentsen, freeview, encoded, demands, ashe, glenn, guarded,
# Nearest to nobel: runestone, prize, laureate, dramatist, b, chemist, baritone, geologist,
# Nearest to centre: majoritarian, vegetative, migrated, jules, recite, lion, sortavala, aristocratic,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4975 0.0958 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5033 0.0946 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4820 0.0952 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5166 0.0953 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4933 0.0952 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4961 0.0955 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4842 0.0961 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4135 0.0959 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4325 0.0973 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4250 0.0970 sec/batch
# Nearest to where: hiragana, represents, fudge, correctly, sqrt, chatting, lances, bradykinin,
# Nearest to six: three, lowe, fiscally, zero, naturalist, balfour, philanthropist, leap,
# Nearest to nine: seven, churchill, turkmenistan, owen, arts, ethnography, papa, tramp,
# Nearest to years: elis, bighorn, bultmann, supersessionism, welding, jacinto, imt, negatives,
# Nearest to d: ois, fran, graham, galahad, writer, musician, hendrik, settling,
# Nearest to first: biennial, liston, ic, takers, dworkin, basilica, yugoslavia, donations,
# Nearest to by: tombo, roosevelts, voortrekkers, exemplar, downwind, tard, endeavors, transept,
# Nearest to on: pekka, amphitheatre, earless, barred, pehr, hypertalk, instantly, dictated,
# Nearest to older: jeet, constricted, gaseous, kern, unfiltered, moabites, narain, clover,
# Nearest to prince: percy, wtro, milestone, swimmer, born, austria, marco, colourful,
# Nearest to brother: takano, wars, abbasid, dmitry, granules, argyll, teleoperation, italian,
# Nearest to existence: lexical, amniotes, repelling, lymphatic, ramses, myself, airflow, offending,
# Nearest to running: endosymbiotic, dominance, gaps, fired, dissertation, disconnect, muzzleloaders, evening,
# Nearest to stage: wallis, bentsen, freeview, ashe, discomfort, demands, lesions, guarded,
# Nearest to nobel: runestone, dramatist, laureate, prize, baritone, geologist, chemist, eloquent,
# Nearest to centre: majoritarian, vegetative, migrated, africaine, recite, jules, aristocratic, sortavala,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4451 0.0980 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4015 0.0969 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4573 0.0963 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3818 0.0970 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4035 0.0975 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4272 0.0965 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3580 0.0954 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3815 0.0961 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3934 0.0955 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4086 0.0953 sec/batch
# Nearest to where: hiragana, sqrt, lances, chatting, fudge, sweets, represents, suru,
# Nearest to six: three, zero, lowe, philanthropist, naturalist, balfour, fiscally, flavorings,
# Nearest to nine: seven, churchill, owen, turkmenistan, ethnography, deux, papa, arts,
# Nearest to years: elis, imt, bighorn, supersessionism, bultmann, expectancy, welding, hara,
# Nearest to d: ois, fran, graham, galahad, hendrik, lafur, settling, ken,
# Nearest to first: biennial, liston, ic, takers, pieces, swordsmanship, basilica, clausewitz,
# Nearest to by: tombo, exemplar, voortrekkers, legitimately, roosevelts, definitions, downwind, timeslot,
# Nearest to on: amphitheatre, tryin, barred, earless, pekka, hoodoo, destiny, instantly,
# Nearest to older: jeet, constricted, kern, gaseous, narain, moabites, minus, clover,
# Nearest to prince: percy, wtro, austria, swimmer, marco, born, secretaries, colourful,
# Nearest to brother: takano, teleoperation, dmitry, abbasid, argyll, wars, protectress, italian,
# Nearest to existence: amniotes, lexical, repelling, lymphatic, phaistos, life, ramses, myself,
# Nearest to running: endosymbiotic, fired, dominance, gaps, muzzleloaders, disconnect, dissertation, abm,
# Nearest to stage: wallis, bentsen, freeview, discomfort, greifswald, lesions, ashe, glenn,
# Nearest to nobel: laureate, runestone, dramatist, prize, geologist, chemist, physicist, emmanuelle,
# Nearest to centre: majoritarian, africaine, vegetative, industries, migrated, circumnavigated, recite, sortavala,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3690 0.0968 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3650 0.0944 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3634 0.0949 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3518 0.0946 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3991 0.0950 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3543 0.0947 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3857 0.0940 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3750 0.0945 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3387 0.0951 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3311 0.0953 sec/batch
# Nearest to where: hiragana, lances, sqrt, deform, represents, provinces, suru, fudge,
# Nearest to six: three, zero, bartolommeo, flavorings, lowe, balfour, fiscally, menger,
# Nearest to nine: seven, turkmenistan, churchill, hdi, owen, ethnography, macarthur, japan,
# Nearest to years: elis, bultmann, supersessionism, bighorn, expectancy, imt, welding, scout,
# Nearest to d: ois, fran, graham, galahad, hendrik, lafur, settling, suffolk,
# Nearest to first: biennial, liston, ic, ppn, swordsmanship, takers, pieces, constraints,
# Nearest to by: exemplar, tombo, voortrekkers, inefficient, legitimately, timeslot, spyglass, livebearers,
# Nearest to on: amphitheatre, earless, tryin, barred, election, instantly, hoodoo, pekka,
# Nearest to older: jeet, constricted, narain, kern, age, minus, gaseous, moabites,
# Nearest to prince: percy, austria, wtro, marco, henry, swimmer, elector, earl,
# Nearest to brother: takano, abbasid, dmitry, teleoperation, argyll, wars, sword, king,
# Nearest to existence: lexical, amniotes, life, repelling, findings, lymphatic, argued, usefully,
# Nearest to running: gaps, dominance, endosymbiotic, fired, muzzleloaders, evening, bhangra, disconnect,
# Nearest to stage: wallis, bentsen, freeview, discomfort, lesions, encoded, banality, demands,
# Nearest to nobel: laureate, runestone, prize, dramatist, chemist, physicist, dobruja, authoritarianism,
# Nearest to centre: majoritarian, industries, africaine, aristocratic, vegetative, migrated, jules, circumnavigated,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3497 0.0971 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2574 0.0956 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3731 0.0947 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3886 0.0955 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3756 0.0951 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2961 0.0955 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3191 0.0958 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3368 0.0946 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1950 0.0952 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2964 0.0955 sec/batch
# Nearest to where: hiragana, sqrt, suru, represents, lances, riposte, chatting, deform,
# Nearest to six: three, zero, one, two, naturalist, five, bartolommeo, philanthropist,
# Nearest to nine: seven, hdi, turkmenistan, churchill, one, owen, runways, ethnography,
# Nearest to years: elis, infant, est, supersessionism, births, bighorn, bultmann, expectancy,
# Nearest to d: ois, fran, hendrik, galahad, graham, writer, chemist, lafur,
# Nearest to first: biennial, liston, ppn, swordsmanship, basilica, takers, qingdao, pieces,
# Nearest to by: exemplar, tombo, voortrekkers, spyglass, roosevelts, livebearers, timeslot, downwind,
# Nearest to on: amphitheatre, tryin, barred, nominating, earless, election, hypertalk, dispensations,
# Nearest to older: jeet, kern, constricted, age, narain, minus, moabites, gaseous,
# Nearest to prince: percy, austria, earl, elector, marco, swimmer, throne, secretaries,
# Nearest to brother: argyll, takano, dmitry, teleoperation, abbasid, wars, sequel, sword,
# Nearest to existence: amniotes, lexical, repelling, findings, life, phaistos, somerled, usefully,
# Nearest to running: dominance, muzzleloaders, gaps, endosymbiotic, fired, terminator, evening, bhangra,
# Nearest to stage: wallis, bentsen, freeview, discomfort, ashe, glenn, banality, boyz,
# Nearest to nobel: laureate, prize, chemist, physicist, dramatist, runestone, geologist, entrepreneur,
# Nearest to centre: majoritarian, africaine, industries, migrated, aristocratic, circumnavigated, northumberland, jules,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3141 0.0959 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3063 0.0950 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3210 0.0423 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2607 0.0949 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2547 0.0941 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2324 0.0943 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2018 0.0943 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2102 0.0941 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2175 0.0946 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1789 0.0945 sec/batch
# Nearest to where: hiragana, sqrt, suru, represents, deform, lances, riposte, provinces,
# Nearest to six: three, zero, one, bartolommeo, two, five, philanthropist, naturalist,
# Nearest to nine: seven, turkmenistan, hdi, churchill, owen, japan, gish, ethnography,
# Nearest to years: elis, bultmann, welding, infant, adult, bighorn, births, scout,
# Nearest to d: ois, fran, hendrik, galahad, graham, lafur, griffith, chemist,
# Nearest to first: biennial, liston, ppn, takers, second, as, oslo, clausewitz,
# Nearest to by: tombo, exemplar, spyglass, roosevelts, pamir, voortrekkers, groundwater, doj,
# Nearest to on: amphitheatre, tryin, earless, barred, olympias, instantly, nominating, dispensations,
# Nearest to older: age, jeet, kern, constricted, narain, median, moabites, families,
# Nearest to prince: percy, elector, earl, austria, throne, marco, xii, rocha,
# Nearest to brother: argyll, teleoperation, dmitry, takano, abbasid, wars, eldest, sword,
# Nearest to existence: amniotes, lexical, repelling, usefully, phaistos, somerled, life, findings,
# Nearest to running: dominance, muzzleloaders, gaps, endosymbiotic, folded, fired, evening, bhangra,
# Nearest to stage: wallis, freeview, bentsen, discomfort, banality, lesions, mains, boyz,
# Nearest to nobel: prize, laureate, chemist, physicist, geologist, dramatist, thierry, runestone,
# Nearest to centre: majoritarian, historic, industries, aristocratic, africaine, northumberland, migrated, circumnavigated,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2401 0.0957 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2352 0.0947 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2292 0.0956 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1246 0.0956 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1835 0.0965 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1610 0.0962 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1654 0.0965 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1932 0.0960 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2211 0.0958 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1732 0.0964 sec/batch
# Nearest to where: hiragana, sqrt, represents, suru, riposte, provinces, lances, m,
# Nearest to six: three, zero, two, one, five, bartolommeo, four, flavorings,
# Nearest to nine: seven, turkmenistan, hdi, churchill, owen, est, macarthur, runways,
# Nearest to years: adult, births, infant, elis, welding, bultmann, female, expectancy,
# Nearest to d: ois, hendrik, fran, galahad, settling, theorem, lafur, exchanging,
# Nearest to first: biennial, ppn, liston, second, takers, clausewitz, as, oslo,
# Nearest to by: tombo, exemplar, spyglass, voortrekkers, roosevelts, livebearers, timeslot, legitimately,
# Nearest to on: amphitheatre, tryin, barred, instantly, earless, olympias, reduce, hypertalk,
# Nearest to older: age, jeet, constricted, kern, families, narain, median, moabites,
# Nearest to prince: percy, earl, elector, xii, marco, consorts, menezes, botanical,
# Nearest to brother: takano, teleoperation, dmitry, argyll, abbasid, faustus, staircase, cannonball,
# Nearest to existence: amniotes, lexical, repelling, usefully, life, phaistos, somerled, myself,
# Nearest to running: dominance, muzzleloaders, gaps, evening, folded, fired, endosymbiotic, goblet,
# Nearest to stage: wallis, bentsen, freeview, discomfort, lesions, mains, banality, diatonic,
# Nearest to nobel: prize, laureate, physicist, thierry, chemist, geologist, runestone, dramatist,
# Nearest to centre: majoritarian, historic, industries, drilled, geologists, aeronautical, tones, africaine,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1664 0.0966 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2254 0.0948 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1926 0.0962 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1853 0.0973 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1820 0.0985 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1798 0.0977 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2256 0.0974 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1598 0.0975 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1304 0.0975 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1931 0.0992 sec/batch
# Nearest to where: hiragana, sqrt, provinces, suru, riposte, represents, lances, deform,
# Nearest to six: three, zero, one, two, five, nine, four, eight,
# Nearest to nine: seven, turkmenistan, one, six, est, hdi, churchill, runways,
# Nearest to years: adult, infant, births, female, rate, mortality, months, expectancy,
# Nearest to d: ois, fran, hendrik, galahad, lafur, settling, griffith, graham,
# Nearest to first: biennial, as, liston, ppn, second, takers, clausewitz, pieces,
# Nearest to by: tombo, exemplar, spyglass, voortrekkers, livebearers, inefficient, interpretive, legitimately,
# Nearest to on: amphitheatre, tryin, barred, olympias, muscovy, of, reduce, dispensations,
# Nearest to older: age, jeet, kern, constricted, narain, families, median, moabites,
# Nearest to prince: percy, throne, consorts, xii, earl, elector, menezes, goldsworthy,
# Nearest to brother: takano, teleoperation, argyll, dmitry, abbasid, faustus, protectress, eldest,
# Nearest to existence: amniotes, lexical, repelling, life, usefully, phaistos, phenotypes, provable,
# Nearest to running: dominance, muzzleloaders, gaps, evening, folded, fired, bhangra, goblet,
# Nearest to stage: wallis, bentsen, freeview, mains, discomfort, boyz, banality, diatonic,
# Nearest to nobel: prize, laureate, physicist, chemist, thierry, emmanuelle, hodges, geologist,
# Nearest to centre: historic, majoritarian, geologists, industries, drilled, sortavala, northumberland, aeronautical,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2221 0.1012 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1988 0.0979 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1968 0.0980 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1972 0.0990 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1538 0.1005 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1572 0.1005 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1751 0.1013 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1526 0.1004 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1785 0.0993 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2135 0.1001 sec/batch
# Nearest to where: hiragana, provinces, riposte, suru, sqrt, represents, deform, devout,
# Nearest to six: three, zero, one, two, eight, four, five, nine,
# Nearest to nine: seven, one, six, turkmenistan, two, churchill, barrington, gish,
# Nearest to years: adult, months, births, female, infant, expectancy, barbarians, elis,
# Nearest to d: ois, fran, hendrik, galahad, lafur, chemist, settling, graham,
# Nearest to first: biennial, liston, as, second, ppn, rgermeister, oslo, clausewitz,
# Nearest to by: exemplar, tombo, spyglass, voortrekkers, interpretive, adenauer, the, livebearers,
# Nearest to on: amphitheatre, tryin, barred, of, nominating, pehr, olympias, submitted,
# Nearest to older: age, kern, jeet, constricted, families, narain, median, moabites,
# Nearest to prince: percy, throne, menezes, xii, earl, consorts, elector, emperor,
# Nearest to brother: argyll, teleoperation, abbasid, dmitry, takano, faustus, eldest, protectress,
# Nearest to existence: repelling, amniotes, somerled, lexical, usefully, simplicity, phenotypes, phaistos,
# Nearest to running: dominance, gaps, muzzleloaders, evening, folded, goblet, bhangra, crook,
# Nearest to stage: wallis, bentsen, freeview, discomfort, banality, mains, boyz, ashe,
# Nearest to nobel: prize, laureate, chemist, physicist, recipient, geneticist, biochemist, geologist,
# Nearest to centre: historic, northumberland, majoritarian, aristocratic, drilled, industries, sortavala, dubrovnik,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2100 0.1004 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1555 0.0995 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1433 0.0990 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1530 0.0985 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0499 0.0993 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1343 0.0991 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1518 0.0986 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1529 0.0983 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1507 0.0165 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1597 0.0984 sec/batch
# Nearest to where: hiragana, provinces, sqrt, riposte, suru, lances, mathbf, m,
# Nearest to six: three, zero, one, two, four, five, eight, seven,
# Nearest to nine: seven, one, turkmenistan, two, six, churchill, ussr, hdi,
# Nearest to years: months, female, adult, infant, births, expectancy, fertility, rate,
# Nearest to d: ois, fran, hendrik, galahad, settling, lafur, griffith, chemist,
# Nearest to first: biennial, liston, as, clausewitz, ppn, second, takers, paradiso,
# Nearest to by: exemplar, tombo, interpretive, spyglass, voortrekkers, the, rolle, livebearers,
# Nearest to on: amphitheatre, tryin, of, barred, isdb, hypertalk, reduce, pehr,
# Nearest to older: age, families, kern, jeet, median, constricted, narain, females,
# Nearest to prince: percy, throne, consorts, menezes, earl, elector, xii, rocha,
# Nearest to brother: argyll, abbasid, teleoperation, dmitry, takano, faustus, eldest, protectress,
# Nearest to existence: amniotes, repelling, somerled, usefully, phenotypes, lexical, phaistos, simplicity,
# Nearest to running: gaps, dominance, muzzleloaders, folded, gtb, evening, structures, mvp,
# Nearest to stage: wallis, bentsen, discomfort, freeview, mains, banality, boyz, lesions,
# Nearest to nobel: prize, laureate, physicist, chemist, agnelli, biochemist, thierry, recipient,
# Nearest to centre: historic, northumberland, aristocratic, industries, drilled, shopping, airport, majoritarian,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1000 0.0991 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0685 0.0967 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0748 0.0964 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0535 0.0962 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0863 0.0968 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0311 0.0958 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0806 0.0946 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0927 0.0949 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1343 0.0952 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0449 0.0945 sec/batch
# Nearest to where: hiragana, sqrt, provinces, suru, deform, riposte, mathbf, lances,
# Nearest to six: three, zero, one, two, five, four, seven, eight,
# Nearest to nine: seven, turkmenistan, one, ussr, six, hdi, two, est,
# Nearest to years: months, adult, female, births, infant, expectancy, welding, rate,
# Nearest to d: ois, fran, hendrik, settling, galahad, lafur, chemist, loathed,
# Nearest to first: biennial, as, second, liston, clausewitz, ppn, lse, pieces,
# Nearest to by: tombo, exemplar, spyglass, the, voortrekkers, state, doj, interpretive,
# Nearest to on: amphitheatre, tryin, barred, of, reduce, hypertalk, dispensations, pehr,
# Nearest to older: age, families, median, kern, jeet, constricted, females, narain,
# Nearest to prince: percy, consorts, throne, menezes, elector, earl, rightful, rocha,
# Nearest to brother: argyll, teleoperation, dmitry, faustus, abbasid, takano, thyestes, cannonball,
# Nearest to existence: amniotes, repelling, somerled, usefully, phenotypes, lexical, simplicity, lewiec,
# Nearest to running: dominance, gaps, muzzleloaders, folded, endosymbiotic, structures, swivel, disconnect,
# Nearest to stage: wallis, discomfort, bentsen, mains, banality, freeview, nisj, lesions,
# Nearest to nobel: prize, laureate, chemist, physicist, agnelli, biochemist, thierry, recipient,
# Nearest to centre: historic, aristocratic, northumberland, palace, industries, refurbished, shopping, drilled,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0098 0.0961 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0207 0.0954 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0351 0.0952 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0643 0.0946 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0787 0.0944 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0562 0.0946 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0700 0.0943 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1130 0.0941 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0640 0.0935 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0441 0.0940 sec/batch
# Nearest to where: hiragana, sqrt, riposte, mathbf, suru, completions, chip, provinces,
# Nearest to six: three, zero, two, one, four, seven, eight, five,
# Nearest to nine: seven, one, six, two, turkmenistan, est, hdi, five,
# Nearest to years: adult, months, female, births, rate, expectancy, five, infant,
# Nearest to d: ois, settling, fran, hendrik, galahad, exchanging, limba, theorem,
# Nearest to first: biennial, as, second, liston, ppn, clausewitz, paradiso, lse,
# Nearest to by: tombo, interpretive, spyglass, exemplar, the, voortrekkers, state, rolle,
# Nearest to on: amphitheatre, tryin, reduce, barred, of, leds, the, dispensations,
# Nearest to older: age, families, median, kern, females, constricted, jeet, narain,
# Nearest to prince: percy, consorts, throne, menezes, elector, earl, rocha, ushant,
# Nearest to brother: argyll, teleoperation, dmitry, takano, faustus, thyestes, abbasid, stillborn,
# Nearest to existence: repelling, usefully, amniotes, somerled, phenotypes, simplicity, lexical, multiplications,
# Nearest to running: dominance, muzzleloaders, gaps, folded, mvp, goblet, swivel, structures,
# Nearest to stage: wallis, bentsen, mains, banality, discomfort, nisj, freeview, boyz,
# Nearest to nobel: prize, laureate, chemist, physicist, biochemist, choo, thierry, recipient,
# Nearest to centre: historic, aristocratic, northumberland, refurbished, industries, drilled, shopping, palace,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0691 0.0949 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0828 0.0934 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0643 0.0931 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0766 0.0928 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0689 0.0934 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0644 0.0930 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0972 0.0932 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0424 0.0930 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0753 0.0924 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0692 0.0927 sec/batch
# Nearest to where: hiragana, sqrt, riposte, provinces, lances, mathbf, suru, spot,
# Nearest to six: three, zero, one, two, four, seven, eight, five,
# Nearest to nine: seven, one, turkmenistan, est, two, six, ussr, five,
# Nearest to years: months, adult, births, female, expectancy, five, rate, infant,
# Nearest to d: settling, fran, ois, hendrik, galahad, limba, loathed, och,
# Nearest to first: as, biennial, liston, second, paradiso, clausewitz, ppn, rgermeister,
# Nearest to by: tombo, the, spyglass, voortrekkers, interpretive, state, exemplar, legitimately,
# Nearest to on: amphitheatre, tryin, barred, supervise, submitted, of, pehr, reduce,
# Nearest to older: age, families, median, kern, jeet, females, constricted, narain,
# Nearest to prince: throne, consorts, percy, elector, princes, earl, menezes, rightful,
# Nearest to brother: argyll, teleoperation, dmitry, faustus, takano, abbasid, thyestes, succeeded,
# Nearest to existence: repelling, amniotes, usefully, somerled, phenotypes, simplicity, lexical, multiplications,
# Nearest to running: dominance, gaps, muzzleloaders, folded, evening, swivel, structures, mvp,
# Nearest to stage: wallis, bentsen, mains, discomfort, nisj, banality, freeview, lesions,
# Nearest to nobel: prize, laureate, chemist, physicist, biochemist, choo, recipient, thierry,
# Nearest to centre: aristocratic, historic, northumberland, hants, refurbished, palace, dubrovnik, beaumaris,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0467 0.0948 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0355 0.0936 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0223 0.0937 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0928 0.0936 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0319 0.0929 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1237 0.0926 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1099 0.0929 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0191 0.0938 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0274 0.0932 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0582 0.0925 sec/batch
# Nearest to where: hiragana, sqrt, riposte, mathbf, represents, provinces, lances, suru,
# Nearest to six: three, zero, one, four, two, eight, five, seven,
# Nearest to nine: seven, one, six, two, ussr, five, zero, four,
# Nearest to years: months, adult, births, five, female, infant, expectancy, rate,
# Nearest to d: ois, fran, settling, galahad, hendrik, och, loathed, spatial,
# Nearest to first: biennial, as, second, liston, ppn, paradiso, clausewitz, lse,
# Nearest to by: tombo, spyglass, voortrekkers, interpretive, the, viktor, exemplar, demerger,
# Nearest to on: tryin, amphitheatre, barred, pehr, reduce, of, submitted, leds,
# Nearest to older: age, families, median, kern, females, jeet, constricted, six,
# Nearest to prince: throne, percy, consorts, menezes, elector, rightful, earl, princes,
# Nearest to brother: argyll, faustus, dmitry, teleoperation, takano, abbasid, stillborn, gagn,
# Nearest to existence: repelling, amniotes, somerled, usefully, tatiana, phenotypes, postings, provable,
# Nearest to running: dominance, gaps, muzzleloaders, folded, structures, mvp, swivel, varsity,
# Nearest to stage: wallis, bentsen, mains, discomfort, banality, nisj, freeview, lesions,
# Nearest to nobel: prize, laureate, chemist, physicist, biochemist, choo, recipient, geneticist,
# Nearest to centre: aristocratic, historic, northumberland, refurbished, shopping, hants, dubrovnik, palace,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9863 0.0937 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0250 0.0932 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0399 0.0929 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0199 0.0930 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0714 0.0939 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0420 0.0821 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0110 0.0928 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9865 0.0932 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0151 0.0922 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9618 0.0924 sec/batch
# Nearest to where: hiragana, sqrt, riposte, mathbf, lances, deform, suru, spot,
# Nearest to six: three, zero, one, eight, four, two, seven, five,
# Nearest to nine: seven, one, six, five, two, zero, four, eight,
# Nearest to years: months, adult, female, births, five, infant, expectancy, literacy,
# Nearest to d: ois, fran, settling, hendrik, galahad, chemist, griffith, writer,
# Nearest to first: as, biennial, second, liston, clausewitz, ppn, takers, eisenach,
# Nearest to by: tombo, voortrekkers, the, interpretive, spyglass, rolle, exemplar, heaviside,
# Nearest to on: amphitheatre, tryin, barred, the, of, dispensations, pehr, archery,
# Nearest to older: age, families, median, kern, females, jeet, constricted, six,
# Nearest to prince: percy, consorts, throne, menezes, elector, princes, earl, rocha,
# Nearest to brother: argyll, teleoperation, dmitry, faustus, takano, thyestes, stillborn, abbasid,
# Nearest to existence: repelling, amniotes, usefully, somerled, provable, phenotypes, postings, realization,
# Nearest to running: dominance, gaps, muzzleloaders, folded, compatibility, swivel, structures, mvp,
# Nearest to stage: mains, wallis, bentsen, discomfort, nisj, banality, lesions, freeview,
# Nearest to nobel: prize, laureate, chemist, physicist, biochemist, recipient, choo, agnelli,
# Nearest to centre: historic, refurbished, northumberland, aristocratic, industries, hants, shopping, internationalization,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9908 0.0940 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9236 0.0931 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9865 0.0923 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0110 0.0929 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0108 0.0931 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0264 0.0935 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9148 0.0940 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9478 0.0937 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9404 0.0937 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9779 0.0936 sec/batch
# Nearest to where: sqrt, hiragana, riposte, mathbf, suru, provinces, chip, rotating,
# Nearest to six: three, zero, one, four, eight, two, seven, five,
# Nearest to nine: seven, one, five, six, zero, two, four, eight,
# Nearest to years: months, births, adult, five, female, zero, expectancy, migrant,
# Nearest to d: settling, ois, fran, hendrik, galahad, exchanging, spatial, och,
# Nearest to first: as, second, biennial, was, ppn, lse, liston, the,
# Nearest to by: the, spyglass, voortrekkers, tombo, interpretive, rolle, state, clintons,
# Nearest to on: tryin, amphitheatre, barred, reduce, supervise, maniac, scoreboard, leds,
# Nearest to older: age, families, median, kern, females, six, jeet, constricted,
# Nearest to prince: consorts, percy, throne, menezes, angie, rocha, princes, rightful,
# Nearest to brother: argyll, teleoperation, takano, dmitry, thyestes, faustus, stillborn, gagn,
# Nearest to existence: repelling, usefully, amniotes, somerled, provable, simplicity, phenotypes, multiplications,
# Nearest to running: dominance, gaps, folded, muzzleloaders, swivel, structures, mvp, handing,
# Nearest to stage: mains, wallis, bentsen, discomfort, nisj, banality, lesions, diatonic,
# Nearest to nobel: prize, laureate, chemist, physicist, biochemist, choo, recipient, geneticist,
# Nearest to centre: historic, refurbished, northumberland, shopping, aristocratic, hants, industries, beaumaris,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9805 0.0949 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0030 0.0937 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9514 0.0935 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0192 0.0937 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0427 0.0926 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9572 0.0927 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0099 0.0934 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0261 0.0931 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9738 0.0933 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0078 0.0932 sec/batch
# Nearest to where: sqrt, hiragana, riposte, chip, suru, rotating, completions, spot,
# Nearest to six: three, zero, one, eight, seven, four, two, five,
# Nearest to nine: one, seven, six, two, zero, five, eight, four,
# Nearest to years: months, adult, female, births, five, expectancy, infant, overnight,
# Nearest to d: ois, fran, settling, galahad, hendrik, slavoj, och, chemist,
# Nearest to first: as, second, biennial, was, the, paradiso, liston, clausewitz,
# Nearest to by: the, spyglass, voortrekkers, interpretive, state, tombo, rolle, of,
# Nearest to on: tryin, amphitheatre, the, barred, of, isdb, external, leds,
# Nearest to older: age, median, families, kern, females, six, constricted, jeet,
# Nearest to prince: throne, consorts, percy, rightful, princes, rocha, ashikaga, menezes,
# Nearest to brother: argyll, takano, dmitry, teleoperation, thyestes, faustus, stillborn, abbasid,
# Nearest to existence: repelling, amniotes, usefully, provable, somerled, simplicity, phenotypes, multiplications,
# Nearest to running: dominance, gaps, muzzleloaders, folded, swivel, mvp, handing, gtb,
# Nearest to stage: mains, bentsen, wallis, nisj, banality, discomfort, diatonic, lesions,
# Nearest to nobel: prize, laureate, physicist, biochemist, chemist, recipient, choo, geneticist,
# Nearest to centre: historic, refurbished, aristocratic, hants, shopping, industries, northumberland, internationalization,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0005 0.0934 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9858 0.0927 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9949 0.0927 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9959 0.0929 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9983 0.0925 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9663 0.0926 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9952 0.0930 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9421 0.0935 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9586 0.0933 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0296 0.0937 sec/batch
# Nearest to where: riposte, hiragana, sqrt, lances, suru, differently, volo, rotating,
# Nearest to six: three, one, zero, eight, four, two, seven, five,
# Nearest to nine: one, seven, two, five, six, zero, four, eight,
# Nearest to years: months, births, female, adult, five, overnight, zero, infant,
# Nearest to d: settling, ois, fran, galahad, limba, perlman, hendrik, slavoj,
# Nearest to first: as, biennial, second, was, the, paradiso, liston, ppn,
# Nearest to by: the, voortrekkers, spyglass, tombo, state, of, a, represented,
# Nearest to on: the, tryin, amphitheatre, barred, of, external, submitted, isdb,
# Nearest to older: age, median, families, kern, females, six, constricted, jeet,
# Nearest to prince: throne, consorts, percy, princes, rightful, regency, emperor, menezes,
# Nearest to brother: argyll, takano, thyestes, teleoperation, faustus, dmitry, stillborn, abbasid,
# Nearest to existence: repelling, amniotes, usefully, somerled, messianic, provable, simplicity, merozoites,
# Nearest to running: dominance, gaps, muzzleloaders, folded, swivel, gtb, structures, dump,
# Nearest to stage: nisj, mains, bentsen, discomfort, wallis, banality, diploid, diatonic,
# Nearest to nobel: prize, laureate, chemist, physicist, choo, biochemist, recipient, geneticist,
# Nearest to centre: historic, aristocratic, northumberland, industries, shopping, internationalization, hants, refurbished,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9626 0.0941 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1070 0.0927 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0231 0.0932 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0460 0.0929 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9462 0.0933 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9582 0.0936 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9736 0.0926 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8128 0.0946 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8518 0.0943 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8843 0.0948 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8413 0.0942 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8715 0.0940 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9215 0.0935 sec/batch
# Nearest to where: riposte, volo, elocution, can, times, tulane, fights, receive,
# Nearest to six: three, zero, one, eight, four, seven, five, two,
# Nearest to nine: one, eight, two, seven, three, five, six, zero,
# Nearest to years: five, months, births, zero, over, nearly, six, age,
# Nearest to d: settling, spatial, roxbury, exchanging, peale, perez, breve, perlman,
# Nearest to first: the, second, was, as, in, which, after, a,
# Nearest to by: the, a, of, and, from, to, as, in,
# Nearest to on: the, a, of, which, is, external, in, zero,
# Nearest to older: age, median, families, females, household, four, kern, six,
# Nearest to prince: consorts, angie, princes, regency, principality, princess, eleonore, mitcham,
# Nearest to brother: stillborn, quintilian, takano, his, elder, father, faustus, eldest,
# Nearest to existence: repelling, usefully, merozoites, prana, assumption, somerled, amniotes, intelligent,
# Nearest to running: dominance, handing, run, folded, metallized, gaps, vanities, presiding,
# Nearest to stage: diploid, lesions, nisj, tapestry, pino, natives, il, tadpoles,
# Nearest to nobel: prize, laureate, biochemist, choo, recipient, physicist, economist, chemist,
# Nearest to centre: shopping, istanbul, refurbished, media, northumberland, internationalization, sofia, industries,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8492 0.0950 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8491 0.0941 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8619 0.0940 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8483 0.0944 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8396 0.0937 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8929 0.0944 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8273 0.0943 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8653 0.0934 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8999 0.0929 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8606 0.0933 sec/batch
# Nearest to where: riposte, volo, can, times, elocution, fights, bigg, receive,
# Nearest to six: three, one, zero, four, eight, seven, five, two,
# Nearest to nine: one, eight, three, two, seven, zero, five, four,
# Nearest to years: five, months, zero, births, over, nearly, six, infant,
# Nearest to d: settling, spatial, roxbury, peale, aleksandrovich, perez, breve, praetorius,
# Nearest to first: the, second, as, was, in, which, after, a,
# Nearest to by: the, of, a, and, in, as, to, one,
# Nearest to on: the, a, of, which, external, is, in, zero,
# Nearest to older: median, age, families, females, six, younger, kern, no,
# Nearest to prince: consorts, princes, principality, princess, angie, regency, eleonore, throne,
# Nearest to brother: stillborn, takano, quintilian, father, eldest, elder, sister, his,
# Nearest to existence: repelling, merozoites, usefully, somerled, prana, assumption, amniotes, intelligent,
# Nearest to running: dominance, handing, run, gaps, folded, presiding, vanities, metallized,
# Nearest to stage: diploid, lesions, nisj, tapestry, pino, outside, honour, il,
# Nearest to nobel: prize, laureate, biochemist, recipient, choo, physicist, literature, economist,
# Nearest to centre: media, shopping, istanbul, internationalization, refurbished, northumberland, employers, hants,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8532 0.0946 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8678 0.0944 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8343 0.0943 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8420 0.0947 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9105 0.0948 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8240 0.0945 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9501 0.0943 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9054 0.0940 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9306 0.0936 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8365 0.0931 sec/batch
# Nearest to where: riposte, times, volo, elocution, can, a, left, mississippi,
# Nearest to six: three, one, four, zero, eight, seven, two, five,
# Nearest to nine: one, eight, two, three, seven, four, five, zero,
# Nearest to years: five, months, zero, over, births, nearly, six, net,
# Nearest to d: settling, spatial, aleksandrovich, peale, roxbury, perez, dwan, praetorius,
# Nearest to first: second, the, was, as, after, which, in, end,
# Nearest to by: the, of, in, and, a, from, as, to,
# Nearest to on: the, a, of, external, in, which, and, zero,
# Nearest to older: median, age, families, females, four, younger, six, kern,
# Nearest to prince: consorts, princes, angie, princess, eleonore, principality, regency, throne,
# Nearest to brother: elder, quintilian, stillborn, eldest, drusus, sister, his, faustus,
# Nearest to existence: repelling, usefully, merozoites, somerled, assumption, intelligent, amniotes, multiplications,
# Nearest to running: dominance, handing, run, vanities, presiding, gaps, folded, infiniband,
# Nearest to stage: diploid, lesions, natives, postponed, nisj, outside, il, pino,
# Nearest to nobel: prize, laureate, biochemist, recipient, prizes, chemist, choo, physicist,
# Nearest to centre: istanbul, shopping, refurbished, northumberland, media, industries, internationalization, sortavala,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8118 0.0940 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8900 0.0929 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7733 0.0937 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8785 0.0935 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8472 0.0935 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8437 0.0929 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9010 0.0451 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8162 0.0928 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8341 0.0933 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8268 0.0925 sec/batch
# Nearest to where: riposte, volo, times, elocution, can, screech, a, chatting,
# Nearest to six: one, three, eight, four, seven, zero, five, two,
# Nearest to nine: one, eight, seven, two, four, three, five, six,
# Nearest to years: months, five, over, births, nearly, zero, net, migrant,
# Nearest to d: settling, one, aleksandrovich, scientist, spatial, three, writer, peale,
# Nearest to first: the, second, was, in, as, after, which, end,
# Nearest to by: the, of, in, a, and, from, which, two,
# Nearest to on: the, of, a, is, in, external, which, zero,
# Nearest to older: median, age, families, females, younger, four, six, daughters,
# Nearest to prince: consorts, princess, princes, angie, regency, eleonore, throne, mitcham,
# Nearest to brother: his, father, elder, sister, takano, stillborn, faustus, quintilian,
# Nearest to existence: repelling, usefully, merozoites, assumption, pirin, god, amniotes, prana,
# Nearest to running: dominance, run, handing, presiding, gaps, folded, vanities, metallized,
# Nearest to stage: diploid, lesions, nisj, postponed, outside, debuted, natives, pino,
# Nearest to nobel: prize, laureate, biochemist, recipient, chemist, physicist, economist, prizes,
# Nearest to centre: shopping, refurbished, istanbul, media, northumberland, internationalization, industries, tallest,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8502 0.0938 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8302 0.0926 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8140 0.0932 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7691 0.0937 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8439 0.0931 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8531 0.0936 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8823 0.0939 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7709 0.0940 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8161 0.0943 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8029 0.0942 sec/batch
# Nearest to where: riposte, can, volo, times, a, every, left, at,
# Nearest to six: one, three, four, zero, eight, seven, five, two,
# Nearest to nine: one, eight, two, seven, four, three, five, zero,
# Nearest to years: five, months, over, zero, births, six, nearly, net,
# Nearest to d: settling, spatial, perez, roxbury, principalities, dwan, exchanging, peale,
# Nearest to first: the, second, was, as, in, which, after, end,
# Nearest to by: the, of, a, and, in, as, which, to,
# Nearest to on: the, a, of, is, in, external, which, zero,
# Nearest to older: age, median, families, four, females, six, younger, household,
# Nearest to prince: consorts, angie, princess, regency, princes, mitcham, eleonore, throne,
# Nearest to brother: mcduff, his, takano, elder, drusus, dmitry, sister, faustus,
# Nearest to existence: repelling, usefully, merozoites, amniotes, assumption, god, provable, pirin,
# Nearest to running: dominance, handing, run, folded, gaps, presiding, metallized, retain,
# Nearest to stage: diploid, lesions, postponed, natives, pino, nisj, outside, debuted,
# Nearest to nobel: prize, laureate, biochemist, prizes, recipient, chemist, physicist, inertial,
# Nearest to centre: shopping, istanbul, refurbished, media, northumberland, internationalization, airport, corridor,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7432 0.0952 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8103 0.0936 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8729 0.0939 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8557 0.0944 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8108 0.0931 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8775 0.0934 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8293 0.0938 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8374 0.0942 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8257 0.0939 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8153 0.0940 sec/batch
# Nearest to where: riposte, left, can, volo, a, elocution, times, fights,
# Nearest to six: three, one, four, zero, eight, seven, five, two,
# Nearest to nine: one, eight, two, seven, three, zero, four, five,
# Nearest to years: five, months, zero, over, births, nearly, six, infant,
# Nearest to d: settling, spatial, dwan, principalities, aleksandrovich, breve, perez, roxbury,
# Nearest to first: the, second, was, as, which, in, after, a,
# Nearest to by: the, of, a, in, and, from, to, as,
# Nearest to on: the, a, of, is, in, which, external, with,
# Nearest to older: age, median, families, females, four, household, younger, six,
# Nearest to prince: consorts, princess, throne, regency, princes, angie, eleonore, principality,
# Nearest to brother: takano, mcduff, elder, sister, eldest, stillborn, drusus, faustus,
# Nearest to existence: repelling, merozoites, usefully, amniotes, assumption, multiplications, pirin, ultimately,
# Nearest to running: dominance, run, handing, gaps, presiding, folded, compatibility, metallized,
# Nearest to stage: diploid, pino, lesions, best, postponed, natives, il, debuted,
# Nearest to nobel: prize, laureate, biochemist, prizes, recipient, physicist, chemist, economist,
# Nearest to centre: shopping, media, istanbul, internationalization, northumberland, refurbished, employers, industries,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8839 0.0950 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8070 0.0938 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8262 0.0942 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8335 0.0940 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8735 0.0954 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8378 0.0946 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8432 0.0939 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8545 0.0936 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8079 0.0944 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7959 0.0940 sec/batch
# Nearest to where: riposte, can, volo, times, left, a, every, phimosis,
# Nearest to six: three, one, four, zero, eight, two, five, seven,
# Nearest to nine: one, eight, two, three, seven, four, five, zero,
# Nearest to years: five, zero, months, over, births, nearly, six, seven,
# Nearest to d: settling, spatial, praetorius, breve, dwan, principalities, roxbury, perez,
# Nearest to first: the, second, was, as, in, after, which, created,
# Nearest to by: the, in, of, a, and, from, to, as,
# Nearest to on: the, a, of, is, to, which, in, and,
# Nearest to older: median, age, families, four, six, younger, females, household,
# Nearest to prince: consorts, princes, princess, throne, regency, eleonore, angie, principality,
# Nearest to brother: sister, takano, elder, mcduff, stillborn, eyed, drusus, eldest,
# Nearest to existence: repelling, merozoites, usefully, somerled, assumption, ultimately, pirin, amniotes,
# Nearest to running: dominance, run, handing, presiding, compatibility, gaps, retain, folded,
# Nearest to stage: diploid, lesions, nisj, postponed, best, pino, il, outside,
# Nearest to nobel: prize, laureate, biochemist, recipient, prizes, literature, chemist, economist,
# Nearest to centre: istanbul, northumberland, shopping, refurbished, internationalization, media, employers, trustees,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8662 0.0957 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8190 0.0948 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9202 0.0946 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9222 0.0941 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9076 0.0947 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8353 0.0940 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7915 0.0938 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8346 0.0932 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7278 0.0941 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8497 0.0945 sec/batch
# Nearest to where: riposte, can, times, volo, elocution, a, left, chatting,
# Nearest to six: one, three, four, zero, eight, seven, two, five,
# Nearest to nine: one, eight, two, seven, three, four, five, zero,
# Nearest to years: five, zero, over, months, births, six, nearly, seven,
# Nearest to d: settling, spatial, peale, praetorius, dwan, roxbury, three, one,
# Nearest to first: the, was, second, after, in, as, end, which,
# Nearest to by: the, in, of, a, and, from, which, as,
# Nearest to on: the, external, a, of, is, in, to, which,
# Nearest to older: median, age, families, four, females, younger, six, kern,
# Nearest to prince: consorts, princes, regency, princess, throne, eleonore, angie, principality,
# Nearest to brother: sister, elder, mcduff, takano, quintilian, drusus, eldest, faustus,
# Nearest to existence: repelling, usefully, merozoites, ultimately, horst, somerled, ontological, assumption,
# Nearest to running: dominance, handing, run, presiding, stranglehold, gaps, vanities, isps,
# Nearest to stage: diploid, lesions, postponed, best, nisj, pino, natives, nominations,
# Nearest to nobel: prize, laureate, biochemist, recipient, prizes, choo, chemist, economist,
# Nearest to centre: istanbul, shopping, northumberland, refurbished, media, internationalization, magdeburg, news,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8619 0.0955 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8233 0.0947 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
